# %% [markdown]
# # Practicing the Python .plot() API standard on Pandas library
# ### Running off preliminary commits to [nu_open_policing](https://github.com/ACiDS-NU/nu_open_policing) by [Matt Kirschner](https://github.com/kirschner21)

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter('ignore')
# %matplotlib inline 
# iPython magic, only works in Jupyter / iPython

# %% [markdown]
# # Read IL-clean.csv with Pandas

# %%
full=pd.read_csv('IL-clean.csv',low_memory=False)
full.head() #Note the nice CSS rendering of Panda DataFrames in notebook
# Out:
#                id state   stop_date stop_time              location_raw  \
# 0  IL-2004-000001    IL  2004-01-01     00:02  ILLINOIS STATE POLICE 17
# 1  IL-2004-000002    IL  2004-01-01     00:07  ILLINOIS STATE POLICE 07
# 2  IL-2004-000003    IL  2004-01-01     00:14  ILLINOIS STATE POLICE 11
# 3  IL-2004-000004    IL  2004-01-01     00:15  ILLINOIS STATE POLICE 03
# 4  IL-2004-000005    IL  2004-01-01     00:15  ILLINOIS STATE POLICE 09
#
#    county_name  county_fips fine_grained_location      police_department  \
# 0          NaN          NaN                    17  Illinois State Police
# 1          NaN          NaN                    07  Illinois State Police
# 2          NaN          NaN                    11  Illinois State Police
# 3  Cook County      17031.0                    03  Illinois State Police
# 4          NaN          NaN                    09  Illinois State Police
#
#   driver_gender            ...             search_conducted  search_type_raw  \
# 0             F            ...                        False              NaN
# 1             M            ...                        False              NaN
# 2             M            ...                        False              NaN
# 3             F            ...                        False              NaN
# 4             F            ...                        False              NaN
#
#   search_type contraband_found     stop_outcome is_arrested  stop_duration  \
# 0         NaN            False  Written Warning         NaN            NaN
# 1         NaN            False  Written Warning         NaN            NaN
# 2         NaN            False         Citation         NaN            NaN
# 3         NaN            False         Citation         NaN            NaN
# 4         NaN            False         Citation         NaN            NaN
#
#   vehicle_type drugs_related_stop                  district
# 0    Olds 2000                NaN  ILLINOIS STATE POLICE 17
# 1    Linc 1990                NaN  ILLINOIS STATE POLICE 07
# 2    Chev 1996                NaN  ILLINOIS STATE POLICE 11
# 3    Buic 1992                NaN  ILLINOIS STATE POLICE 03
# 4    Olds 1996                NaN  ILLINOIS STATE POLICE 09
#
# [5 rows x 26 columns]

# %% [markdown]
# # Tabulated data has 26 columns

# %%
full.columns
# Out:
# Index(['id', 'state', 'stop_date', 'stop_time', 'location_raw', 'county_name',
#        'county_fips', 'fine_grained_location', 'police_department',
#        'driver_gender', 'driver_age_raw', 'driver_age', 'driver_race_raw',
#        'driver_race', 'violation_raw', 'violation', 'search_conducted',
#        'search_type_raw', 'search_type', 'contraband_found', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'vehicle_type', 'drugs_related_stop',
#        'district'],
#       dtype='object')

# %% [markdown]
# # Summarize Data
# Note: $\text{'hit' rate} = \frac{\text{number of times contraband found}}{\text{numer of searches conducted}}$

# %%
def SummaryStats(df, label):
    """
    Sums searches, stops, and hits + calcs search rate in df; 
    returns a single row data frame with 'label' as index
    """
    n_stops = df.shape[0]
    n_searches = df['search_conducted'].sum()
    n_hits = df['contraband_found'].sum()
    search_rate = n_searches / n_stops
    hit_rate = n_hits / n_searches
    td = {'n_stops' : n_stops,
          'n_searches' : n_searches,
          'n_hits' : n_hits,
          'search_rate' : search_rate,
          'hit_rate' : hit_rate}
    return pd.DataFrame(data=td,index=[label])

# %% [markdown]
# # Summarize by race

# %%
SummarizedStops = SummaryStats(full, 'AllStops')

for race in full['driver_race'].unique():
    temp = SummaryStats(full[full['driver_race'] == race], race + 'Stops')
    SummarizedStops = SummarizedStops.append(temp)

SummarizedStops
# Out:
#                n_stops  n_searches  n_hits  search_rate  hit_rate
# AllStops       4715031      188728   38733     0.040027  0.205232
# WhiteStops     3437483       89166   21865     0.025939  0.245217
# BlackStops      796114       64810   12507     0.081408  0.192979
# HispanicStops   360294       31877    3977     0.088475  0.124761
# AsianStops      111758        2562     339     0.022925  0.132319
# OtherStops        9382         313      45     0.033362  0.143770

# %%
# This is a slow cell to run, it totals race hit rate by policing district
LocationStops = SummaryStats(full,'Total')
LocationStops['race'] = 'All'
LocationStops['location'] = 'All'
LocationStops['White_hit_rate'] = SummarizedStops.loc['WhiteStops']['hit_rate']
LocationStops['White_search_rate'] = SummarizedStops.loc['WhiteStops']['search_rate']

for district in full['district'].unique():
    if not isinstance(district, str):
        continue
    tempwhite = SummaryStats(full[(full['driver_race'] == 'White') & 
                                  (full['district'] == district)],
                             'White' + ' in ' + district)
    whitehit = tempwhite.get_value('White' + ' in ' + district, 'hit_rate')
    whitesearch = tempwhite.get_value('White' + ' in ' + district, 'search_rate')
    for race in full['driver_race'].unique():        
        if race == 'White':
            temp = tempwhite
        elif race == 'Other':
            continue
        else: 
            temp = SummaryStats(full[(full['driver_race'] == race) &
                                   (full['district'] == district)],
                              race + ' in ' + district)
        temp['race'] = race
        temp['location'] = district
        temp['White_hit_rate'] = whitehit
        temp['White_search_rate'] = whitesearch
        LocationStops = LocationStops.append(temp)
# Out:
# C:\Users\Jordan\Miniconda3\envs\dotplot\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\Jordan\Miniconda3\envs\dotplot\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\Jordan\Miniconda3\envs\dotplot\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   if __name__ == '__main__':

# %% [markdown]
# # Group by Race

# %%
ByRace = LocationStops.groupby('race')
print(ByRace.describe(include = [np.number]).columns.levels[0])
print('# of Stops')
ByRace.describe(include = [np.number]).n_stops.drop(index='All', columns='count')
# Out:
# Index(['White_hit_rate', 'White_search_rate', 'hit_rate', 'n_hits',
#        'n_searches', 'n_stops', 'search_rate'],
#       dtype='object')
# # of Stops
#                    mean           std    min        25%       50%        75%  \
# race
# Asian       4656.083333   6315.054228    9.0    1511.25    2722.5    4897.00
# Black      33170.625000  44125.297090  152.0    7957.50   22908.5   36202.50
# Hispanic   15009.833333  23395.216521   69.0    3445.75    8431.5   10972.25
# White     143221.166667  94379.107666  216.0  111217.25  137700.5  176226.75
#
#                max
# race
# Asian      29148.0
# Black     201600.0
# Hispanic   91312.0
# White     483157.0

# %% [markdown]
# # Visualizating data, plotting
# ## Matplotlib from Scratch (in sub-slide)

# %%
fig, ax = plt.subplots()
for name, group in ByRace:
    if name != 'All':
        ax.plot(group.White_search_rate, group.search_rate,
                marker = 'o', linestyle = '', label = name)

ax.legend()
ax.set_xlabel("White Search rate")
ax.set_ylabel("Search rate (by race)")
ax.set_title("Given Race Search Rate in a Policing District vs. White Search Rate")
plt.show() #suppresses <matplotlib...> output (from ax.legend() for ex.)

# %% [markdown]
# ... Hope you're not missing the sub-context here:<br>
# **White, Asian people get searched less often by police in traffice stops**

# %% [markdown]
# # Pandas [DataFrame.plot](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) functionality
# ## 'de-facto standard for 2D charts'

# %%
name_list = []
group_list = []
for name, group in ByRace:
    if name!= 'All':
        name_list.append(name)
        group_list.append(group)

# %%
index = 1
group_list[index].plot(x = 'White_search_rate',
                       y = 'search_rate',
                       kind = 'scatter',
                       title = name_list[index] + ' search rate')
plt.show()

# %% [markdown]
# Note axes are automatically labeled<br>
# In general, fast and easy to explore correlation in DataFrame

# %% [markdown]
# You can even do some cool stuff with color/colorbars in the blink of an eye<br>
# Note: using [DataFrame.plot.scatter](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.scatter.html) here to skip verbose
# ```python
# kind = 'scatter'
# ```

# %%
index = 1
group_list[index].plot.scatter(x = 'White_search_rate',
                               y = 'search_rate',
                               c = 'White_search_rate', 
                               title = name_list[index])
plt.show()

# %% [markdown]
# Looking at a plot like this, realize the x data could be encoded on colorbar <br>
# --> probably more elegant that search rate should just be in units of `white_search_rate`, and then just have a y axis and colorbar of `search_rate/white_search_rate`
# ¯\ _ (ツ) _ /¯

# %% [markdown]
# # ... Again, though, this is best for 2D charts
# Left a blank code block here to try to recreate Matt's multi-scatter plot above with DataFrame.plot<br>
# (Answer on the next subslide)

# %%
# Note: You can edit this cell even in presentation mode and run with {'shift' + 'enter'}

# %%
prop_cycle = plt.rcParams['axes.prop_cycle'] 
colors = prop_cycle.by_key()['color']
#^^from https://matplotlib.org/2.1.1/gallery/color/color_cycle_default.html

ax1 = group_list[0].plot.scatter(x = 'White_search_rate', y = 'search_rate')
for i in range(1, len(group_list)):
    group_list[i].plot.scatter(x = 'White_search_rate', 
                               y = 'search_rate', 
                               color = colors[i], 
                               ax = ax1, #here is the key fix 
                               legend = True)
    ax1.legend(name_list)

# %% [markdown]
# # What about Plotly, Vega-Lite, Bokeh, etc?
# Same, same (protocol), but different<br>
# First, here's a figure to orient you in the Python visualizatoin world<br>
# <img src="image.png" alt="A Map of Visualization in Python in 2018" width="600"/>

# %% [markdown]
# And here's a matplotlib plot, again, but of 'hit' rate instead, <br> because y'know *"maybe there are just less white people getting searched?"*

# %%
fig, ax = plt.subplots()
for name, group in ByRace:
    ax.plot(group.White_hit_rate,
            group.hit_rate,
            marker = 'o',
            linestyle = '',
            label = name)

ax.legend(loc = 'upper left')
ax.set_xlabel("White 'Hit' rate")
ax.set_ylabel("'Hit' rate (by race)")
ax.set_title("Given Race 'Hit' Rate in a Policing District vs. White 'Hit' Rate")
plt.show()

# %% [markdown]
# # Vega-lite on a DataFrame with [pdvega](https://altair-viz.github.io/pdvega/)
# "When working with data, one of the biggest challenges is ensuring reproducibility of results. When you create a figure and export it to PNG or PDF, the data become baked-in to the rendering in a way that is difficult or impossible for others to extract. Vega and Vega-Lite change this: instead of packaging a figure by encoding its pixel values, they package a figure by describing, in a declarative manner, the relationship between data values and visual encodings through a JSON specification. This means that the Vega-Lite figures produced by pdvega are portable: you can send someone the resulting JSON specification and they can choose whether to render it interactively online, convert it to a PNG or EPS for static publication, or even enhance and extend the figure to learn more about the data."
#
# **tl; dr** *Vega visuals are in JSON; JSON is more portable (JSON == (python) dictionary)*

# %% [markdown]
# # Here's the sticking point:
# If you understand the `DataFrame.plot` demo above, you already know how to use `pdvega`

# %%
import pdvega  # import adds vgplot attribute to pandas
index = 1
group_list[index].vgplot.scatter(x = 'White_hit_rate',
                               y = 'hit_rate', 
                               title = name_list[index])
# Out:
# <div class="vega-embed" id="498775a3-02f2-400d-b46d-c617777b0304"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %% [markdown]
# ^^This is even cooler for data exploration

# %% [markdown]
# Sadly, I cannot get `vgplot` to stack scatter plots on top of each other<br>
# You can however,
# ```python
# from pdvega import Axes
# ```
# which, may start to show you the [verbose](https://altair-viz.github.io/pdvega/advanced.html) syntax to encode JSON images (even in this 'lite form); this is why pdvega is *so* nice

# %% [markdown]
# # cufflinks, hvPlot, and beyond
# The `dotplot.yml` environment file in this repo provides the variables to run [cufflinks](https://plot.ly/ipython-notebooks/cufflinks/#dataframes) and [hvPlot](https://hvplot.pyviz.org/user_guide/Plotting.html) libraries, giving access to DataFrame.plot-like API for [Plotly](https://plot.ly/python/) and [Bokeh](https://bokeh.pydata.org/en/latest/) (both are JavaScript-based). <br>
#
# "hvPlot also provides the same plotting API for many other data libraries (xarray, GeoPandas, Dask, Intake, Streamz)"<br>
#
# Please toy around with these if you have time--first on my list is GeoPandas since policing precinct is encoded in this data and might make for a great [mapped](http://geopandas.org/mapping.html) plot

# %% [markdown]
# # Below is some additional analysis of the data

# %%
LocationStops['diff_hit_rate']=LocationStops['hit_rate']/LocationStops['White_hit_rate']
LocationStops['diff_search_rate']=LocationStops['search_rate']/LocationStops['White_search_rate']

# %%
fig, ax = plt.subplots()
for name, group in ByRace:
    ax.plot(group.diff_search_rate, group.diff_hit_rate, marker='o',linestyle='',label=name)
    
ax.legend()

# %%
LocationStops
# Out:
#                                       hit_rate  n_hits  n_searches  n_stops  \
# Total                                 0.205232   38733      188728  4715031
# White in ILLINOIS STATE POLICE 17     0.241595     733        3034   105809
# Black in ILLINOIS STATE POLICE 17     0.240000     294        1225    11890
# Hispanic in ILLINOIS STATE POLICE 17  0.175676     130         740     9013
# Asian in ILLINOIS STATE POLICE 17     0.173469      17          98     2280
# White in ILLINOIS STATE POLICE 07     0.219691     839        3819   145611
# Black in ILLINOIS STATE POLICE 07     0.234101     254        1085    14840
# Hispanic in ILLINOIS STATE POLICE 07  0.170762     139         814     9037
# Asian in ILLINOIS STATE POLICE 07     0.161765      22         136     2733
# White in ILLINOIS STATE POLICE 11     0.257607    1380        5357   216970
# Black in ILLINOIS STATE POLICE 11     0.305459    1662        5441    67507
# Hispanic in ILLINOIS STATE POLICE 11  0.195238     164         840     7373
# Asian in ILLINOIS STATE POLICE 11     0.214286      21          98     3766
# White in ILLINOIS STATE POLICE 03     0.131699     779        5915   180546
# Black in ILLINOIS STATE POLICE 03     0.123050    2674       21731   201600
# Hispanic in ILLINOIS STATE POLICE 03  0.096221     830        8626    74840
# Asian in ILLINOIS STATE POLICE 03     0.091816      46         501    16653
# White in ILLINOIS STATE POLICE 09     0.277804    1736        6249   174787
# Black in ILLINOIS STATE POLICE 09     0.266936     926        3469    34402
# Hispanic in ILLINOIS STATE POLICE 09  0.094926     116        1222     8841
# Asian in ILLINOIS STATE POLICE 09     0.198020      20         101     4347
# White in ILLINOIS STATE POLICE 08     0.214138     827        3862   145808
# Black in ILLINOIS STATE POLICE 08     0.221670     446        2012    23346
# Hispanic in ILLINOIS STATE POLICE 08  0.136364      42         308     4599
# Asian in ILLINOIS STATE POLICE 08     0.153846      10          65     3134
# White in ILLINOIS STATE POLICE 15     0.152756    1369        8962   483157
# Black in ILLINOIS STATE POLICE 15     0.168285    1196        7107   117463
# Hispanic in ILLINOIS STATE POLICE 15  0.142573     859        6025    91312
# Asian in ILLINOIS STATE POLICE 15     0.088073      48         545    29148
# White in ILLINOIS STATE POLICE 22     0.315607     819        2595   113020
# ...                                        ...     ...         ...      ...
# Hispanic in ILLINOIS STATE POLICE 18  0.207018      59         285     3823
# Asian in ILLINOIS STATE POLICE 18     0.212121       7          33     2308
# White in ILLINOIS STATE POLICE 12     0.304772    2408        7901   198287
# Black in ILLINOIS STATE POLICE 12     0.270888     616        2274    27541
# Hispanic in ILLINOIS STATE POLICE 12  0.122513     117         955     8022
# Asian in ILLINOIS STATE POLICE 12     0.042857       6         140     3407
# White in ILLINOIS STATE POLICE 21     0.235187     258        1097    81432
# Black in ILLINOIS STATE POLICE 21     0.234383     454        1937    38874
# Hispanic in ILLINOIS STATE POLICE 21  0.170825      89         521    10886
# Asian in ILLINOIS STATE POLICE 21     0.131148       8          61     5589
# White in ILLINOIS STATE POLICE 01     0.255730     569        2225   126922
# Black in ILLINOIS STATE POLICE 01     0.171306      80         467     8201
# Hispanic in ILLINOIS STATE POLICE 01  0.170588      87         510     9686
# Asian in ILLINOIS STATE POLICE 01     0.137931       4          29     2712
# White in ILLINOIS STATE POLICE 14     0.314969    1212        3848    89400
# Black in ILLINOIS STATE POLICE 14     0.337037     182         540     4833
# Hispanic in ILLINOIS STATE POLICE 14  0.311005      65         209     2052
# Asian in ILLINOIS STATE POLICE 14     0.230769       6          26      635
# White in ILLINOIS STATE POLICE 04     0.000000       0           1      399
# Black in ILLINOIS STATE POLICE 04     0.333333       1           3      152
# Hispanic in ILLINOIS STATE POLICE 04       NaN       0           0      124
# Asian in ILLINOIS STATE POLICE 04          NaN       0           0       50
# White in ILLINOIS STATE POLICE 00          NaN       0           0      461
# Black in ILLINOIS STATE POLICE 00     0.000000       0           3      171
# Hispanic in ILLINOIS STATE POLICE 00  0.000000       0           1      206
# Asian in ILLINOIS STATE POLICE 00     1.000000       1           1       36
# White in ILLINOIS STATE POLICE Z2          NaN       0           0      216
# Black in ILLINOIS STATE POLICE Z2          NaN       0           0      163
# Hispanic in ILLINOIS STATE POLICE Z2       NaN       0           0       69
# Asian in ILLINOIS STATE POLICE Z2          NaN       0           0        9
#
#                                       search_rate      race  \
# Total                                    0.040027       All
# White in ILLINOIS STATE POLICE 17        0.028674     White
# Black in ILLINOIS STATE POLICE 17        0.103028     Black
# Hispanic in ILLINOIS STATE POLICE 17     0.082104  Hispanic
# White in ILLINOIS STATE POLICE 08           0.214138           0.026487
# Black in ILLINOIS STATE POLICE 08           0.214138           0.026487
# Hispanic in ILLINOIS STATE POLICE 08        0.214138           0.026487
# Asian in ILLINOIS STATE POLICE 08           0.214138           0.026487
# White in ILLINOIS STATE POLICE 15           0.152756           0.018549
# Black in ILLINOIS STATE POLICE 15           0.152756           0.018549
# Hispanic in ILLINOIS STATE POLICE 15        0.152756           0.018549
# Asian in ILLINOIS STATE POLICE 15           0.152756           0.018549
# White in ILLINOIS STATE POLICE 22           0.315607           0.022961
# ...                                              ...                ...
# Hispanic in ILLINOIS STATE POLICE 18        0.332305           0.023775
# Asian in ILLINOIS STATE POLICE 18           0.332305           0.023775
# White in ILLINOIS STATE POLICE 12           0.304772           0.039846
# Black in ILLINOIS STATE POLICE 12           0.304772           0.039846
# Hispanic in ILLINOIS STATE POLICE 12        0.304772           0.039846
# Asian in ILLINOIS STATE POLICE 12           0.304772           0.039846
# White in ILLINOIS STATE POLICE 21           0.235187           0.013471
# Black in ILLINOIS STATE POLICE 21           0.235187           0.013471
# Hispanic in ILLINOIS STATE POLICE 21        0.235187           0.013471
# Asian in ILLINOIS STATE POLICE 21           0.235187           0.013471
# White in ILLINOIS STATE POLICE 01           0.255730           0.017530
# Black in ILLINOIS STATE POLICE 01           0.255730           0.017530
# Hispanic in ILLINOIS STATE POLICE 01        0.255730           0.017530
# Asian in ILLINOIS STATE POLICE 01           0.255730           0.017530
# White in ILLINOIS STATE POLICE 14           0.314969           0.043043
# Black in ILLINOIS STATE POLICE 14           0.314969           0.043043
# Hispanic in ILLINOIS STATE POLICE 14        0.314969           0.043043
# Asian in ILLINOIS STATE POLICE 14           0.314969           0.043043
# White in ILLINOIS STATE POLICE 04           0.000000           0.002506
# Black in ILLINOIS STATE POLICE 04           0.000000           0.002506
# Hispanic in ILLINOIS STATE POLICE 04        0.000000           0.002506
# Asian in ILLINOIS STATE POLICE 04           0.000000           0.002506
# White in ILLINOIS STATE POLICE 00                NaN           0.000000
# Black in ILLINOIS STATE POLICE 00                NaN           0.000000
# Hispanic in ILLINOIS STATE POLICE 00             NaN           0.000000
# Asian in ILLINOIS STATE POLICE 00                NaN           0.000000
# White in ILLINOIS STATE POLICE Z2                NaN           0.000000
# Black in ILLINOIS STATE POLICE Z2                NaN           0.000000
# Hispanic in ILLINOIS STATE POLICE Z2             NaN           0.000000
# Asian in ILLINOIS STATE POLICE Z2                NaN           0.000000
#
#                                       diff_hit_rate  diff_search_rate
# Total                                      0.836941          1.543096
# White in ILLINOIS STATE POLICE 17          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 17          0.993397          3.593034
# Hispanic in ILLINOIS STATE POLICE 17       0.727149          2.863317
# Asian in ILLINOIS STATE POLICE 17          0.718017          1.498988
# White in ILLINOIS STATE POLICE 07          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 07          1.065594          2.787664
# Hispanic in ILLINOIS STATE POLICE 07       0.777281          3.434351
# Asian in ILLINOIS STATE POLICE 07          0.736328          1.897334
# White in ILLINOIS STATE POLICE 11          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 11          1.185755          3.264435
# Hispanic in ILLINOIS STATE POLICE 11       0.757892          4.614377
# Asian in ILLINOIS STATE POLICE 11          0.831832          1.053959
# White in ILLINOIS STATE POLICE 03          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 03          0.934327          3.290200
# Hispanic in ILLINOIS STATE POLICE 03       0.730611          3.518105
# Asian in ILLINOIS STATE POLICE 03          0.697168          0.918287
# White in ILLINOIS STATE POLICE 09          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 09          0.960876          2.820455
# Hispanic in ILLINOIS STATE POLICE 09       0.341702          3.866058
# Asian in ILLINOIS STATE POLICE 09          0.712803          0.649876
# White in ILLINOIS STATE POLICE 08          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 08          1.035175          3.253753
# Hispanic in ILLINOIS STATE POLICE 08       0.636803          2.528462
# Asian in ILLINOIS STATE POLICE 08          0.718445          0.783039
# White in ILLINOIS STATE POLICE 15          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 15          1.101657          3.261884
# Hispanic in ILLINOIS STATE POLICE 15       0.933335          3.557235
# Asian in ILLINOIS STATE POLICE 15          0.576562          1.008024
# White in ILLINOIS STATE POLICE 22          1.000000          1.000000
# ...                                             ...               ...
# Hispanic in ILLINOIS STATE POLICE 18       0.622975          3.135603
# Asian in ILLINOIS STATE POLICE 18          0.638333          0.601393
# White in ILLINOIS STATE POLICE 12          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 12          0.888824          2.072158
# Hispanic in ILLINOIS STATE POLICE 12       0.401983          2.987672
# Asian in ILLINOIS STATE POLICE 12          0.140621          1.031260
# White in ILLINOIS STATE POLICE 21          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 21          0.996582          3.698783
# Hispanic in ILLINOIS STATE POLICE 21       0.726339          3.552695
# Asian in ILLINOIS STATE POLICE 21          0.557631          0.810185
# White in ILLINOIS STATE POLICE 01          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 01          0.669871          3.248306
# Hispanic in ILLINOIS STATE POLICE 01       0.667063          3.003534
# Asian in ILLINOIS STATE POLICE 01          0.539361          0.609979
# White in ILLINOIS STATE POLICE 14          1.000000          1.000000
# Black in ILLINOIS STATE POLICE 14          1.070065          2.595849
# Hispanic in ILLINOIS STATE POLICE 14       0.987415          2.366309
# Asian in ILLINOIS STATE POLICE 14          0.732673          0.951266
# White in ILLINOIS STATE POLICE 04               NaN          1.000000
# Black in ILLINOIS STATE POLICE 04               inf          7.875000
# Hispanic in ILLINOIS STATE POLICE 04            NaN          0.000000
# Asian in ILLINOIS STATE POLICE 04               NaN          0.000000
# White in ILLINOIS STATE POLICE 00               NaN               NaN
# Black in ILLINOIS STATE POLICE 00               NaN               inf
# Hispanic in ILLINOIS STATE POLICE 00            NaN               inf
# Asian in ILLINOIS STATE POLICE 00               NaN               inf
# White in ILLINOIS STATE POLICE Z2               NaN               NaN
# Black in ILLINOIS STATE POLICE Z2               NaN               NaN
# Hispanic in ILLINOIS STATE POLICE Z2            NaN               NaN
# Asian in ILLINOIS STATE POLICE Z2               NaN               NaN
#
# [97 rows x 11 columns]
